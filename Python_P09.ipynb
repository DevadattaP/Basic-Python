# %% [markdown]
# **Exception handling**

# %%
a,b = [int(x) for x in input('Enter two numbers: ').split()]
print(a/b)
# Out:
# Enter two numbers: 5 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-4-0d9727d3f2fd> in <module>
#       1 a,b = [int(x) for x in input('Enter two numbers: ').split()]
# ----> 2 print(a/b)
#
# ZeroDivisionError: division by zero

# %%
try:
    a,b=[int(x) for x in input('Enter two numbers: ').split()]
    print(a/b)
except ZeroDivisionError:
    print('Cannot divide by zero')
# Out:
# Enter two numbers: 5 2
# 2.5

# %%
try:
    a,b=[int(x) for x in input('Enter two numbers: ').split()]
    print(a/b)
except ZeroDivisionError:
    print('Cannot divide by zero')
# Out:
# Enter two numbers: 5 0
# Cannot divide by zero

# %%
list1=[2,3,4,5]
print(list1[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-3739df05b3cd> in <module>
#       1 list1=[2,3,4,5]
# ----> 2 print(list1[4])
#
# IndexError: list index out of range

# %%
list1=[2,3,4,5]
try:
    print(list1[4])
except IndexError as ex:
    print(ex)
# Out:
# list index out of range

# %%
print("start")
x=0
list1=[2,3,4,5]
try:
    print("this part gets executed")
    result=10/x
    print("""this part which is written after occurence of 
    exception, does not gets executed""") 
    print(list1[4])
    print(result)
except ZeroDivisionError:
     print("you can't div by zero")
except IndexError as ex:
        print(ex)
print("end")
# Out:
# start
# this part gets executed
# you can't div by zero
# end

# %%
print("start")
x=0
list1=[2,3,4,5]
try:
    result=10/x
    print(list1[2])
    print(result)
except Exception as ex:
     print(ex)
finally:
    print("finally block")
    
print("end")
# Out:
# start
# division by zero
# finally block
# end

# %%
print("start")
x=0
list1=[2,3,4,5]
try:
    print(list1[4])
    result=10/x
    print(result)
except Exception as ex:
     print(ex)
else:
    print("else block")
finally:
    print("finally block")
    
print("end")
# Out:
# start
# list index out of range
# finally block
# end

# %%
print("start")
x=2
list1=[2,3,4,5]
try:
    result=10/x
    print(list1[2])
    print(result)
except Exception as ex:
     print(ex)
else:
    print("else block")
finally:
    print("finally block")
    
print("end")
# Out:
# start
# 4
# 5.0
# else block
# finally block
# end

# %%
print("start")
x=0
list1=[2,3,4,5]
try:
    result=10/x
    print(result)
    print(list1[4])
except Exception as ex:
     print(ex)
else:
    print("else block")
finally:
    print("finally block")
    try:
        print(list1[4])
    except Exception as ex:
        print(ex)
    
print("end")
# Out:
# start
# division by zero
# finally block
# list index out of range
# end

# %%
try:
    x=10
    y='days'
    print(x+y)
except TypeError:
    print('you cannot add string with number')
# Out:
# you cannot add string with number
