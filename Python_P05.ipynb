# %%
# Mount your google drive in google colab 
from google.colab import drive 
drive.mount('/content/drive')
# Insert the directory to python path 
import sys 
sys.path.insert(0,'/content/drive/My Drive/Colab Notebooks')
# Out:
# Mounted at /content/drive

# %%
f = open('/content/drive/My Drive/Colab Notebooks/Devadatta.txt','r')
print('Cursor position =',f.tell())
print(f.read())
print('Cursor position =',f.tell())
print('Is file closed ?',f.closed)
f.close()
print('Is file closed ?',f.closed)
# Out:
# Cursor position = 0
# Hello, my name is Devadatta.
# Cursor position = 28
# Is file closed ? False
# Is file closed ? True

# %%
f = open('/content/drive/My Drive/Colab Notebooks/Devadatta.txt','r+')
print('Cursor position =',f.tell())
print(f.read())
temp=f.tell()
print('Cursor position =',temp)
f.write('FAMT CSE')
print('Cursor position =',f.tell())
f.seek(temp)
print(f.read())
f.seek(0)
print(f.read())
# Out:
# Cursor position = 0
# Hello, my name is Devadatta.
# Cursor position = 28
# Cursor position = 36
# FAMT CSE
# Hello, my name is Devadatta.FAMT CSE

# %%
f.close()

# %%
with open('/content/drive/My Drive/Colab Notebooks/Devadatta.txt','r') as f:
    data = f.read()
print(data)
print(f.closed)
g = open('/content/drive/My Drive/Colab Notebooks/Devadatta1.txt','w+')
g.write(data)
g.seek(0)
print(g.read())
g.close()
# Out:
# Hello, my name is Devadatta.FAMT CSE
# True
# Hello, my name is Devadatta.FAMT CSE

# %%
f = open('/content/drive/My Drive/Colab Notebooks/Devadatta2.txt','wb+')
f.write('My name is Devadatta'.encode())
f.write('\n'.encode())
f.write('Branch\tCSE(AI&ML)'.encode())
f.seek(0)
print(f.read())
f.close()
f=open('/content/drive/My Drive/Colab Notebooks/Devadatta2.txt','r')
print(f.read())
f.close()
# Out:
# b'My name is Devadatta\nBranch\tCSE(AI&ML)'
# My name is Devadatta
# Branch	CSE(AI&ML)

# %%
f=open('/content/drive/My Drive/Colab Notebooks/Devadatta2.txt','a+')
f.write('\nClass\tSE\nRoll No\t50')
f.seek(0)
print(f.read())
# Out:
# My name is Devadatta
# Branch	CSE(AI&ML)
# Class	SE
# Roll No	50

# %%
f=open('/content/drive/My Drive/Colab Notebooks/Devadatta.txt','r')
print(f.read())
f.seek(0)
print(f.readline())
for line in f:
    print(line)
f.close()
# Out:
# Hello, my name is Devadatta.FAMT CSE
# Class	SE
# Roll No	50
# Hello, my name is Devadatta.FAMT CSE
#
# Class	SE
#
# Roll No	50

# %%
f=open('/content/drive/My Drive/Colab Notebooks/Devadatta.txt','r')
print(f.readline(21))
print(f.readline())
print(f.readline())
# Out:
# Hello, my name is Dev
# adatta.FAMT CSE
#
# Class	SE

# %%
print(type(f))
f.close()
# Out:
# <class '_io.TextIOWrapper'>
