# %% [markdown]
# # **Q 1. Consider any list. And perform all methods on it.**

# %%
num = [1,2,3,3,4,5]
num.append(6)
print(num)
# Out:
# [1, 2, 3, 3, 4, 5, 6]

# %%
num.insert(3,7)
print(num)
# Out:
# [1, 2, 3, 7, 3, 4, 5, 6]

# %%
num.remove(5)
print(num)
# Out:
# [1, 2, 3, 7, 3, 4, 6]

# %%
print(num.pop())
print(num)
# Out:
# 6
# [1, 2, 3, 7, 3, 4]

# %%
print(num.index(4))
# Out:
# 5

# %%
print(num.count(3))
# Out:
# 2

# %%
num.reverse()
print(num)
# Out:
# [4, 3, 7, 3, 2, 1]

# %%
num.sort()
print(num)
# Out:
# [1, 2, 3, 3, 4, 7]

# %%
num.sort(reverse=True)
print(num)
# Out:
# [7, 4, 3, 3, 2, 1]

# %%
new_num=num.copy()
num.clear()
print(num)
print(new_num)
# Out:
# []
# [7, 4, 3, 3, 2, 1]

# %% [markdown]
# # **Q 2. Consider any tuple. And perform given methods on it.**

# %%
tup =(1,4,2,6,9,4,5,4)
print(tup.count(4))
# Out:
# 3

# %%
print(tup[0])
# Out:
# 1

# %%
print(tup[6])
# Out:
# 5

# %%
print(tup.index(9))
# Out:
# 4

# %%
print(len(tup))
# Out:
# 8

# %% [markdown]
# # **Q 3. Consider a Set. Print that set, it’s length and class type.**

# %%
day={'Sun','Mon','Tue','Wen','Thu','Fri','Sat'}
print(day)
# Out:
# {'Mon', 'Fri', 'Thu', 'Sat', 'Wen', 'Sun', 'Tue'}

# %%
print(len(day))
# Out:
# 7

# %%
print(type(day))
# Out:
# <class 'set'>

# %%
day.discard('Mon')
print(day)
# Out:
# {'Fri', 'Thu', 'Sat', 'Wen', 'Sun', 'Tue'}

# %%
day.add('Mon')
print(day)
# Out:
# {'Mon', 'Fri', 'Thu', 'Sat', 'Wen', 'Sun', 'Tue'}

# %%
days=day.copy()
days.pop()
days.remove('Thu')
print(day)
print(days)
print(day.difference(days))
print(day.intersection(days))
# Out:
# {'Mon', 'Fri', 'Thu', 'Sat', 'Wen', 'Sun', 'Tue'}
# {'Mon', 'Wen', 'Sun', 'Fri', 'Tue'}
# {'Sat', 'Thu'}
# {'Mon', 'Fri', 'Wen', 'Sun', 'Tue'}

# %%
days.clear()
print(days)
# Out:
# set()

# %% [markdown]
# # **Q 4. Consider a dictionary. Print that dictionary and its class type.**

# %%
me ={ 'name':'Devadatta',
     'gender':'Male',
     'age':19,
     'role':'student'}
print(me)
print(type(me))
# Out:
# {'name': 'Devadatta', 'gender': 'Male', 'age': 19, 'role': 'student'}
# <class 'dict'>

# %%
me.update({'collage':'FAMT'})
print(me)
# Out:
# {'name': 'Devadatta', 'gender': 'Male', 'age': 19, 'role': 'student', 'collage': 'FAMT'}

# %%
print(me.keys())
print(me.values())
# Out:
# dict_keys(['name', 'gender', 'age', 'role', 'collage'])
# dict_values(['Devadatta', 'Male', 19, 'student', 'FAMT'])

# %%
print(me.pop('age'))
print(me)
# Out:
# 19
# {'name': 'Devadatta', 'gender': 'Male', 'role': 'student', 'collage': 'FAMT'}

# %%
me.get('role')
# Out:
# 'student'

# %%
me.clear()
print(me)
# Out:
# {}

# %% [markdown]
# # **Q 5. Print a string using single, double, triple quotes.**

# %%
s1 = 'Computer'
print(s1)
# Out:
# Computer

# %%
s1 = "Computer"
print(s1)
# Out:
# Computer

# %%
s1 = '''Computer
Science
Engineering'''
print(s1)
# Out:
# Computer
# Science
# Engineering

# %% [markdown]
# # **Q 6. Consider a string and perform given operations on it.**

# %%
s = 'Devadatta@123'
print(s)
# Out:
# Devadatta@123

# %%
len(s)
# Out:
# 13

# %%
s.find('d')
# Out:
# 4

# %%
s.upper()
# Out:
# 'DEVADATTA@123'

# %%
s.lower()
# Out:
# 'devadatta@123'

# %%
s.capitalize()
# Out:
# 'Devadatta@123'

# %%
print(s.isalnum())
print(s.isascii())
# Out:
# False
# True

# %%
s.replace('d','D')
# Out:
# 'DevaDatta@123'

# %%
'@' in s
# Out:
# True

# %%
print(s[0:len(s)])
print(s[:])
print(s[0:])
print(s[:len(s)])
print(s[3:-3])
print(s[2:6])
print(s[5])
# Out:
# Devadatta@123
# Devadatta@123
# Devadatta@123
# Devadatta@123
# adatta@
# vada
# a

# %% [markdown]
# # **Q 7. Write a code to find largest number in list.**

# %%
lis=[6,4,7,2,9,1,3]
max=lis[0]
for i in lis:
  if i>max:
    max=i
print('Maximum number in list is',max)
# Out:
# Maximum number in list is 9

# %% [markdown]
# # **Q 8. Write a code to remove duplicate number in list.**

# %%
dup = [1,2,3,1,2,3,4,5,2,3,5]
ndup=[]
for i in dup:
  if i not in ndup:
    ndup.append(i)
print(ndup)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # **Q 9. Consider a dictionary and get information from dictionary.**

# %%
car = {'name':'Wagon R',
       'company':'Maruti Suzuki',
       'model':'VXI',
       'color':'White',
       'Number':2205}
print(car)
print(car['name'])
print(car.get('model'))
# Out:
# {'name': 'Wagon R', 'company': 'Maruti Suzuki', 'model': 'VXI', 'color': 'White', 'Number': 2205}
# Wagon R
# VXI

# %% [markdown]
# # **Q 10. Write a code for writing a phone number in words using dictionary.**

# %%
phone=input('Enter your mobile number : ')
num_map={'1':'one',
         '2':'two',
         '3':'three',
         '4':'four',
         '5':'five',
         '6':'six',
         '7':'seven',
         '8':'eight',
         '9':'nine',
         '0':'zero'}
for i in phone:
  print(num_map.get(i),end='\t')
# Out:
# Enter your mobile number : 7262044394
# seven	two	six	two	zero	four	four	three	nine	four

# %% [markdown]
# # **Q 11. Write a code for dictionary.**

# %%
info=input('> ').split(' ')
student={'name':'Devadatta',
         'branch':'CSE',
         'batch':'B3'}
for i in info:
  print(student.get(i,i),end=" ")
# Out:
# > Hello! I am name , I am student of branch , and in batch .
# Hello! I am Devadatta , I am student of CSE , and in B3 .
